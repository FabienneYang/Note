# %%
from PIL import Image
import matplotlib.pyplot as plt
from wordcloud import WordCloud, ImageColorGenerator
import jieba
import numpy as np
from collections import Counter

# %%
text_from_file_with_apath = open(r'comment.txt', "r",encoding="utf-8").read()
terms = [t for t in jieba.cut(text_from_file_with_apath, cut_all=True)]
sorted(Counter(terms).items(), key=lambda x:x[1], reverse=True)
# Out:
# [('', 1603),
#  ('，', 1371),
#  ('\n', 899),
#  ('：', 703),
#  ('的', 449),
#  ('。', 307),
#  ('很', 294),
#  ('"', 273),
#  ('速度', 232),
#  ('运行', 215),
#  ('外观', 211),
#  ('了', 205),
#  (' ', 200),
#  ('好', 187),
#  ('行速', 176),
#  ('外形', 150),
#  ('也', 149),
#  ('效果', 141),
#  ('游戏', 137),
#  ('非常', 126),
#  ('屏幕', 122),
#  ('包装', 122),
#  ('不错', 111),
#  ('电脑', 108),
#  ('轻薄', 105),
#  ('散热', 91),
#  ('性能', 90),
#  ('是', 90),
#  ('保护', 86),
#  ('我', 79),
#  ('！', 75),
#  ('用', 73),
#  ('很快', 73),
#  ('可以', 70),
#  ('开机', 70),
#  ('跑', 70),
#  ('画面', 70),
#  ('还', 69),
#  ('分', 66),
#  ('快', 63),
#  ('高', 62),
#  ('都', 62),
#  ('热性', 60),
#  ('程度', 60),
#  ('没有', 60),
#  ('品质', 59),
#  ('流畅', 57),
#  ('不', 55),
#  ('挺', 53),
#  ('喜欢', 52),
#  ('就', 50),
#  ('性价比', 49),
#  ('买', 49),
#  ('这个', 48),
#  ('有', 44),
#  ('清晰', 44),
#  ('其他', 42),
#  ('办公', 42),
#  ('评测', 42),
#  ('好看', 40),
#  ('配置', 40),
#  ('感觉', 39),
#  ('还是', 37),
#  ('满意', 37),
#  ('给', 36),
#  ('问题', 34),
#  ('特色', 33),
#  ('键盘', 33),
#  ('大', 31),
#  ('在', 30),
#  ('值得', 30),
#  ('卡', 30),
#  ('很轻', 29),
#  ('使用', 29),
#  ('漂亮', 28),
#  ('速度快', 28),
#  ('比较', 28),
#  ('玩游', 28),
#  ('玩游戏', 28),
#  ('没', 27),
#  ('就是', 26),
#  ('笔记', 26),
#  ('笔记本', 26),
#  ('这', 25),
#  ('方便', 25),
#  ('小', 24),
#  ('起来', 24),
#  ('。"', 24),
#  ('说', 24),
#  ('.', 23),
#  ('客服', 23),
#  ('和', 23),
#  ('真的', 23),
#  ('特别', 23),
#  ('到', 22),
#  ('京东', 21),
#  ('风扇', 21),
#  ('比', 21),
#  ('宏碁', 21),
#  ('显示', 21),
#  ('服务', 20),
#  ('一次', 20),
#  ('物流', 20),
#  ('着', 20),
#  ('收到', 20),
#  ('舒服', 20),
#  ('吧', 19),
#  ('声音', 19),
#  ('大气', 19),
#  ('购买', 19),
#  ('携带', 19),
#  ('银色', 19),
#  ('618', 19),
#  ('小巧', 19),
#  ('炫', 19),
#  ('酷', 19),
#  ('一个', 19),
#  ('好评', 18),
#  ('一点', 18),
#  ('一直', 18),
#  ('还行', 18),
#  ('体验', 18),
#  ('机器', 18),
#  ('质量', 17),
#  ('能', 17),
#  ('快递', 17),
#  ('价格', 17),
#  ('顿', 17),
#  ('上', 17),
#  ('适合', 16),
#  ('便携', 16),
#  ('这款', 16),
#  ('不是', 16),
#  ('挺快', 16),
#  ('赞', 16),
#  ('软件', 16),
#  ('大师', 16),
#  ('秒', 16),
#  ('目前', 16),
#  ('第一', 16),
#  ('看', 16),
#  ('超', 15),
#  ('很棒', 15),
#  ('选择', 15),
#  ('推荐', 15),
#  ('时间', 15),
#  ('价位', 15),
#  ('戏本', 15),
#  ('开', 15),
#  ('玩', 15),
#  ('有点', 14),
#  ('打开', 14),
#  ('还有', 14),
#  ('色', 14),
#  ('域', 14),
#  ('颜色', 14),
#  ('总体', 14),
#  ('来说', 14),
#  ('整体', 14),
#  ('知道', 14),
#  ('机箱', 14),
#  ('画质', 14),
#  ('很薄', 13),
#  ('价比高', 13),
#  ('比高', 13),
#  ('宏基', 13),
#  ('完全', 13),
#  ('屏', 13),
#  ('金属', 13),
#  (',', 12),
#  ('多', 12),
#  ('处理', 12),
#  ('6', 12),
#  ('设计', 12),
#  ('质感', 12),
#  ('、', 12),
#  ('值', 12),
#  ('薄', 12),
#  ('鲁', 12),
#  ('力', 12),
#  ('自己', 12),
#  ('一下', 12),
#  ('个', 12),
#  ('后', 11),
#  ('背光', 11),
#  ('日常', 11),
#  ('基本', 11),
#  ('内存', 11),
#  ('！"', 11),
#  ('信赖', 11),
#  ('品牌', 11),
#  ('严实', 11),
#  ('系统', 11),
#  ('很多', 11),
#  ('完美', 11),
#  ('不知', 11),
#  ('但是', 11),
#  ('手感', 11),
#  ('时候', 11),
#  ('再', 11),
#  ('超级', 11),
#  ('发热', 11),
#  ('良好', 10),
#  ('机身', 10),
#  ('重量', 10),
#  ('美观', 10),
#  ('购物', 10),
#  ('处理器', 10),
#  ('理器', 10),
#  ('打游戏', 10),
#  ('十代', 10),
#  ('对比', 10),
#  ('颜', 10),
#  ('任何', 10),
#  ('很漂亮', 10),
#  ('简约', 10),
#  ('144hz', 10),
#  ('你', 10),
#  ('好多', 10),
#  ('左右', 10),
#  ('追', 10),
#  ('不会', 10),
#  ('色彩', 10),
#  ('评', 10),
#  ('泡沫', 10),
#  ('视频', 10),
#  ('5', 10),
#  ('第一次', 10),
#  ('看起', 10),
#  ('看起来', 10),
#  ('正常', 10),
#  ('应该', 10),
#  ('激活', 10),
#  ('一台', 10),
#  ('轻', 9),
#  ('到手', 9),
#  ('希望', 9),
#  ('太', 9),
#  ('i5', 9),
#  ('很久', 9),
#  ('啥', 9),
#  ('2', 9),
#  ('温度', 9),
#  ('合适', 9),
#  ('够用', 9),
#  ('关机', 9),
#  ('用来', 9),
#  ('安装', 9),
#  ('硬盘', 9),
#  ('中', 9),
#  ('虽然', 9),
#  ('?', 9),
#  ('耐心', 9),
#  ('显卡', 9),
#  ('最后', 9),
#  ('完整', 9),
#  ('爱', 9),
#  ('评价', 9),
#  ('人', 9),
#  ('售后', 9),
#  ('一般', 8),
#  ('不到', 8),
#  ('东西', 8),
#  ('来', 8),
#  ('选', 8),
#  ('下单', 8),
#  ('轻巧', 8),
#  ('出差', 8),
#  ('需要', 8),
#  ('现在', 8),
#  ('不过', 8),
#  ('指纹', 8),
#  ('1', 8),
#  ('足够', 8),
#  ('而且', 8),
#  ('；', 8),
#  ('无', 8),
#  ('这么', 8),
#  ('三层', 8),
#  ('要', 8),
#  ('帅', 8),
#  ('显示屏', 8),
#  ('反应', 8),
#  ('主机', 8),
#  ('以后', 8),
#  ('挺不错', 8),
#  ('今天', 8),
#  ('刚', 8),
#  ('机子', 8),
#  ('才', 8),
#  ('拥有', 8),
#  ('怎么', 8),
#  ('小时', 8),
#  ('等', 8),
#  ('144', 8),
#  ('点', 7),
#  ('开始', 7),
#  ('一样', 7),
#  ('又', 7),
#  ('15', 7),
#  ('笔记本电脑', 7),
#  ('CPU', 7),
#  ('全', 7),
#  ('3', 7),
#  ('主流', 7),
#  ('带', 7),
#  ('够', 7),
#  ('时尚', 7),
#  ('大概', 7),
#  ('寸', 7),
#  ('一款', 7),
#  ('也好', 7),
#  ('觉得', 7),
#  ('分辨', 7),
#  ('分辨率', 7),
#  ('辨率', 7),
#  ('到位', 7),
#  ('（', 7),
#  ('结实', 7),
#  ('充电', 7),
#  ('测试', 7),
#  ('让', 7),
#  ('常流', 7),
#  ('可', 7),
#  ('双层', 7),
#  ('售后服务', 7),
#  ('!', 6),
#  ('哈哈', 6),
#  ('做', 6),
#  ('接受', 6),
#  ('很严', 6),
#  ('送货', 6),
#  ('指纹识别', 6),
#  ('识别', 6),
#  ('感受', 6),
#  ('只', 6),
#  ('功能', 6),
#  ('下', 6),
#  ('到货', 6),
#  ('细腻', 6),
#  ('棒', 6),
#  ('固态', 6),
#  ('面', 6),
#  ('感', 6),
#  ('之前', 6),
#  ('10', 6),
#  ('别的', 6),
#  ('所以', 6),
#  ('最大', 6),
#  ('确实', 6),
#  ('之后', 6),
#  ('静音', 6),
#  ('顺畅', 6),
#  ('上网', 6),
#  ('几秒', 6),
#  ('一边', 6),
#  ('下载', 6),
#  ('装完', 6),
#  ('两层', 6),
#  ('方面', 6),
#  ('没玩', 6),
#  ('一些', 6),
#  ('里面', 6),
#  ('电', 6),
#  ('总之', 6),
#  ('它', 6),
#  ('看视', 6),
#  ('刷新', 6),
#  ('刷新率', 6),
#  ('已经', 6),
#  ('家里', 6),
#  ('骑士', 6),
#  ('压力', 6),
#  ('热', 6),
#  ('什么', 6),
#  ('主要', 6),
#  ('这样', 6),
#  ('想象', 6),
#  ('清楚', 6),
#  ('跟', 6),
#  ('没用', 6),
#  ('解答', 6),
#  ('能用', 6),
#  ('差', 6),
#  ('做工', 6),
#  ('他', 6),
#  ('过', 6),
#  ('没得', 6),
#  ('塑料', 6),
#  ('期待', 6),
#  ('吃', 6),
#  ('鸡', 6),
#  ('黑色', 5),
#  ('几乎', 5),
#  ('啊', 5),
#  ('再来', 5),
#  ('便宜', 5),
#  ('显', 5),
#  ('走', 5),
#  ('毕竟', 5),
#  ('大家', 5),
#  ('外观设计', 5),
#  ('蛮', 5),
#  ('活动', 5),
#  ('简单', 5),
#  ('office', 5),
#  ('解决', 5),
#  ('一', 5),
#  ('电池', 5),
#  ('模式', 5),
#  ('盖', 5),
#  ('续航', 5),
#  ('非常适合', 5),
#  ('AMD', 5),
#  ('第二', 5),
#  ('感谢', 5),
#  ('下午', 5),
#  ('语音', 5),
#  ('设置', 5),
#  ('超薄', 5),
#  ('出来', 5),
#  ('较轻', 5),
#  ('机时', 5),
#  ('高性', 5),
#  ('看着', 5),
#  ('风格', 5),
#  ('基本上', 5),
#  ('lol', 5),
#  ('真', 5),
#  ('香', 5),
#  ('来看', 5),
#  ('很大', 5),
#  ('物美', 5),
#  ('安全', 5),
#  ('强大', 5),
#  ('好几', 5),
#  ('这家', 5),
#  ('完好', 5),
#  ('联盟', 5),
#  ('影响', 5),
#  ('不大', 5),
#  ('小哥', 5),
#  ('因为', 5),
#  ('竞', 5),
#  ('）', 5),
#  ('以前', 5),
#  ('送', 5),
#  ('符合', 5),
#  ('机', 5),
#  ('毫无', 5),
#  ('～', 5),
#  ('接口', 5),
#  ('相信', 5),
#  ('最高', 5),
#  ('看上', 5),
#  ('看上去', 5),
#  ('上去', 5),
#  ('的话', 5),
#  ('惊艳', 5),
#  ('产品', 5),
#  ('十年', 5),
#  ('用户', 5),
#  ('昨天', 5),
#  ('两个', 5),
#  ('万', 5),
#  ('段时间', 5),
#  ('孩子', 5),
#  ('下手', 5),
#  ('档次', 5),
#  ('用到', 5),
#  ('强', 5),
#  ('帅气', 5),
#  ('看图', 5),
#  ('台电', 5),
#  ('绝对', 4),
#  ('朋友', 4),
#  ('终于', 4),
#  ('大方', 4),
#  ('送到', 4),
#  ('学习', 4),
#  ('防', 4),
#  ('很小', 4),
#  ('度', 4),
#  ('清晰度', 4),
#  ('商务', 4),
#  ('只是', 4),
#  ('控制', 4),
#  ('支持', 4),
#  ('对', 4),
#  ('头', 4),
#  ('0', 4),
#  ('开关', 4),
#  ('开关机', 4),
#  ('高清', 4),
#  ('白', 4),
#  ('挑选', 4),
#  ('相当', 4),
#  ('但', 4),
#  ('重要', 4),
#  ('要是', 4),
#  ('几个', 4),
#  ('稳定', 4),
#  ('包里', 4),
#  ('买到', 4),
#  ('物超所值', 4),
#  ('超高', 4),
#  ('本人', 4),
#  ('14', 4),
#  ('更', 4),
#  ('高大', 4),
#  ('帧', 4),
#  ('秒杀', 4),
#  ('%', 4),
#  ('自动', 4),
#  ('艳丽', 4),
#  ('电脑配置', 4),
#  ('宝贝', 4),
#  ('点亮', 4),
#  ('线', 4),
#  ('专业', 4),
#  ('刚刚', 4),
#  ('刚好', 4),
#  ('纸箱', 4),
#  ('个人', 4),
#  ('万多', 4),
#  ('英雄', 4),
#  ('舒适', 4),
#  ('新机', 4),
#  ('两天', 4),
#  ('谢谢', 4),
#  ('只能', 4),
#  ('不愧', 4),
#  ('入手', 4),
#  ('尤其', 4),
#  ('算是', 4),
#  ('试', 4),
#  ('win10', 4),
#  ('科技', 4),
#  ('轻松', 4),
#  ('惊喜', 4),
#  ('配', 4),
#  ('爽', 4),
#  ('暗影', 4),
#  ('擎', 4),
#  ('网上', 4),
#  ('不能', 4),
#  ('操作', 4),
#  ('台式', 4),
#  ('轻便', 4),
#  ('好久', 4),
#  ('后续', 4),
#  ('一段', 4),
#  ('一段时间', 4),
#  ('待机', 4),
#  ('待机时间', 4),
#  ('多年', 4),
#  ('新', 4),
#  ('还算', 4),
#  ('最', 4),
#  ('不多', 4),
#  ('鼠标', 4),
#  ('整体感', 4),
#  ('点点', 4),
#  ('垃圾', 4),
#  ('眼睛', 4),
#  ('上档', 4),
#  ('上档次', 4),
#  ('精致', 4),
#  ('未', 4),
#  ('情况', 4),
#  ('老', 4),
#  ('发货', 4),
#  ('失望', 4),
#  ('损坏', 4),
#  ('加', 4),
#  ('噪音', 4),
#  ('纸盒', 4),
#  ('包裹', 4),
#  ('地方', 4),
#  ('没得说', 4),
#  ('那', 4),
#  ('RGB', 4),
#  ('！！', 4),
#  ('用心', 4),
#  ('分数', 4),
#  ('各种', 4),
#  ('较', 4),
#  ('月', 4),
#  ('显示器', 4),
#  ('娱乐', 4),
#  ('出', 3),
#  ('一如', 3),
#  ('一如既往', 3),
#  ('既往', 3),
#  ('愉快', 3),
#  ('拿到', 3),
#  ('真是', 3),
#  ('一种', 3),
#  ('下次', 3),
#  ('保障', 3),
#  ('不及', 3),
#  ('待', 3),
#  ('台笔', 3),
#  ('家', 3),
#  ('极', 3),
#  ('迅速', 3),
#  ('简洁', 3),
#  ('18', 3),
#  ('蓝光', 3),
#  ('触感', 3),
#  ('远程', 3),
#  ('公司', 3),
#  ('竟然', 3),
#  ('别', 3),
#  ('，"', 3),
#  ('7', 3),
#  ('16G', 3),
#  ('占', 3),
#  ('价钱', 3),
#  ('作为', 3),
#  ('购机', 3),
#  ('优惠', 3),
#  ('第二天', 3),
#  ('二天', 3),
#  ('人员', 3),
#  ('态度', 3),
#  ('帮', 3),
#  ('从', 3),
#  ('号', 3),
#  ('同时', 3),
#  ('超值', 3),
#  ('窄', 3),
#  ('高性价', 3),
#  ('高性价比', 3),
#  ('类型', 3),
#  ('边框', 3),
#  ('比例', 3),
#  ('超过', 3),
#  ('字', 3),
#  ('联想', 3),
#  ('独', 3),
#  ('贴纸', 3),
#  ('划算', 3),
#  ('其实', 3),
#  ('光', 3),
#  ('级别', 3),
#  ('不出', 3),
#  ('之', 3),
#  ('色彩艳丽', 3),
#  ('卡机', 3),
#  ('大小', 3),
#  ('只用', 3),
#  ('后期', 3),
#  ('各方', 3),
#  ('分区', 3),
#  ('很酷', 3),
#  ('+', 3),
#  ('调', 3),
#  ('正版', 3),
#  ('盒子', 3),
#  ('像', 3),
#  ('图片', 3),
#  ('秒左右', 3),
#  ('电源', 3),
#  ('不了', 3),
#  ('进', 3),
#  ('掉', 3),
#  ('杠杠', 3),
#  ('网速', 3),
#  ('加上', 3),
#  ('移动', 3),
#  ('空间', 3),
#  ('视觉', 3),
#  ('视觉效果', 3),
#  ('老牌', 3),
#  ('牌子', 3),
#  ('Acer', 3),
#  ('哒', 3),
#  ('耐用', 3),
#  ('挑', 3),
#  ('会', 3),
#  ('晚上', 3),
#  ('包着', 3),
#  ('看来', 3),
#  ('默认', 3),
#  ('换', 3),
#  ('工作', 3),
#  ('水平', 3),
#  ('不怎么', 3),
#  ('用用', 3),
#  ('星', 3),
#  ('材质', 3),
#  ('蜂鸟', 3),
#  ('亮丽', 3),
#  ('蓝色', 3),
#  ('nice', 3),
#  ('先', 3),
#  ('马上', 3),
#  ('屏幕显示', 3),
#  ('不重', 3),
#  ('合出', 3),
#  ('差不多', 3),
#  ('电影', 3),
#  ('包', 3),
#  ('不好', 3),
#  ('较快', 3),
#  ('女生', 3),
#  ('佳', 3),
#  ('算', 3),
#  ('真实', 3),
#  ('配送', 3),
#  ('打', 3),
#  ('fps', 3),
#  ('风', 3),
#  ('继续', 3),
#  ('不行', 3),
#  ('没想', 3),
#  ('发现', 3),
#  ('把', 3),
#  ('难', 3),
#  ('本子', 3),
#  ('想', 3),
#  ('72', 3),
#  ('如', 3),
#  ('没测', 3),
#  ('优秀', 3),
#  ('“', 3),
#  ('并且', 3),
#  ('一切', 3),
#  ('天一', 3),
#  ('坏', 3),
#  ('另外', 3),
#  ('广', 3),
#  (':', 3),
#  ('第一台', 3),
#  ('原因', 3),
#  ('十分', 3),
#  ('这种', 3),
#  ('时', 3),
#  ('不在', 3),
#  ('除了', 3),
#  ('本身', 3),
#  ('图', 3),
#  ('一眼', 3),
#  ('模具', 3),
#  ('外壳', 3),
#  ('物美价廉', 3),
#  ('价廉', 3),
#  ('灯', 3),
#  ('实惠', 3),
#  ('各', 3),
#  ('然后', 3),
#  ('人性', 3),
#  ('人性化', 3),
#  ('自定', 3),
#  ('自定义', 3),
#  ('定义', 3),
#  ('大型', 3),
#  ('暂时', 3),
#  ('平时', 3),
#  ('有损', 3),
#  ('丝', 3),
#  ('必须', 3),
#  ('得', 3),
#  ('少', 3),
#  ('4', 3),
#  ('自带', 3),
#  ('8G', 3),
#  ('不少', 3),
#  ('带背光', 3),
#  ('买来', 3),
#  ('无法', 3),
#  ('最好', 3),
#  ('C', 3),
#  ('21', 3),
#  ('有效', 3),
#  ('电脑主机', 3),
#  ('行', 2),
#  ('中间', 2),
#  ('换货', 2),
#  ('以为', 2),
#  ('一般般', 2),
#  ('般般', 2),
#  ('般的', 2),
#  ('不一', 2),
#  ('坠', 2),
#  ('真是太', 2),
#  ('开心', 2),
#  ('同事', 2),
#  ('考虑', 2),
#  ('amd', 2),
#  ('之间', 2),
#  ('角度', 2),
#  ('些', 2),
#  ('迫不及待', 2),
#  ('打打', 2),
#  ('天', 2),
#  ('在家', 2),
#  ('严密', 2),
#  ('首先', 2),
#  ('及时', 2),
#  ('当天', 2),
#  ('平均', 2),
#  ('40', 2),
#  ('-', 2),
#  ('50', 2),
#  ('180', 2),
#  ('开合', 2),
#  ('经常', 2),
#  ('外出', 2),
#  ('畅', 2),
#  ('机关', 2),
#  ('负荷', 2),
#  ('正品', 2),
#  ('货', 2),
#  ('发展', 2),
#  ('要求', 2),
#  ('凑合', 2),
#  ('见', 2),
#  ('想着', 2),
#  ('版', 2),
#  ('指', 2),
#  ('入', 2),
#  ('保证', 2),
#  ('右上', 2),
#  ('吹', 2),
#  ('一大', 2),
#  ('合办', 2),
#  ('样子', 2),
#  ('音质', 2),
#  ('??', 2),
#  ('建议', 2),
#  ('选购', 2),
#  ('趁着', 2),
#  ('担当', 2),
#  ('服人', 2),
#  ('大学', 2),
#  ('学用', 2),
#  ('裸机', 2),
#  ('最重', 2),
#  ('痕迹', 2),
#  ('几款', 2),
#  ('坏点', 2),
#  ('丰富', 2),
#  ('安静', 2),
#  ('拿出', 2),
#  ('轻盈', 2),
#  ('重量轻', 2),
#  ('易', 2),
#  ('贼', 2),
#  ('＋', 2),
#  ('有余', 2),
#  ('9', 2),
#  ('a', 2),
#  ('2060', 2),
#  ('16g', 2),
#  ('17', 2),
#  ('对手', 2),
#  ('#', 2),
#  ('高分', 2),
#  ('多少', 2),
#  ('33w', 2),
#  ('贴', 2),
#  ('果然', 2),
#  ('YES', 2),
#  ('1660TI', 2),
#  ('以内', 2),
#  ('上来', 2),
#  ('是非', 2),
#  ('完善', 2),
#  ('大声', 2),
#  ('总而言之', 2),
#  ('而言', 2),
#  ('实是', 2),
#  ('巨好', 2),
#  ('廉价', 2),
#  ('确保', 2),
#  ('箱内', 2),
#  ('干净', 2),
#  ('整洁', 2),
#  ('灯光', 2),
#  ('灯光效果', 2),
#  ('光效', 2),
#  ('包装材料', 2),
#  ('材料', 2),
#  ('好几家', 2),
#  ('几家', 2),
#  ('公道', 2),
#  ('边下', 2),
#  ('边玩', 2),
#  ('听音', 2),
#  ('音乐', 2),
#  ('拆开', 2),
#  ('31w', 2),
#  ('33', 2),
#  ('一批', 2),
#  ('应用', 2),
#  ('物体', 2),
#  ('损伤', 2),
#  ('四分', 2),
#  ('rgb', 2),
#  ('个人感觉', 2),
#  ('磨损', 2),
#  ('32', 2),
#  ('万分', 2),
#  ('了解', 2),
#  ('调光', 2),
#  ('哦', 2),
#  ('前来', 2),
#  ('吵', 2),
#  ('太多', 2),
#  ('哭', 2),
#  ('很重', 2),
#  ('一开', 2),
#  ('降价', 2),
#  ('还用', 2),
#  ('所', 2),
#  ('能够', 2),
#  ('单手', 2),
#  ('需求', 2),
#  ('属于', 2),
#  ('高性能', 2),
#  ('延迟', 2),
#  ('没下', 2),
#  ('清', 2),
#  ('针', 2),
#  ('百分', 2),
#  ('百分之', 2),
#  ('99', 2),
#  ('i7', 2),
#  ('新一代', 2),
#  ('一代', 2),
#  ('出风口', 2),
#  ('风口', 2),
#  ('合理', 2),
#  ('看到', 2),
#  ('一定', 2),
#  ('很细', 2),
#  ('OK', 2),
#  ('台式机', 2),
#  ('妹妹', 2),
#  ('产品包装', 2),
#  ('装好', 2),
#  ('理好', 2),
#  ('好好', 2),
#  ('捧', 2),
#  ('膜', 2),
#  ('小姐', 2),
#  ('昨天晚上', 2),
#  ('携带方便', 2),
#  ('没什么', 2),
#  ('不够', 2),
#  ('位置', 2),
#  ('上方', 2),
#  ('80', 2),
#  ('关于', 2),
#  ('效率', 2),
#  ('放心', 2),
#  ('该是', 2),
#  ('长', 2),
#  ('先用', 2),
#  ('看看', 2),
#  ('超出', 2),
#  ('预期', 2),
#  ('IPS', 2),
#  ('音效', 2),
#  ('关键', 2),
#  ('电量', 2),
#  ('黄金', 2),
#  ('那么', 2),
#  ('这些', 2),
#  ('鲜艳', 2),
#  ('60', 2),
#  ('还好', 2),
#  ('比起', 2),
#  ('本次', 2),
#  ('且', 2),
#  ('工程', 2),
#  ('认给', 2),
#  ('帮忙', 2),
#  ('差使', 2),
#  ('俩', 2),
#  ('上下', 2),
#  ('课', 2),
#  ('不足', 2),
#  ('可能', 2),
#  ('书包', 2),
#  ('尺寸', 2),
#  ('较大', 2),
#  ('如何', 2),
#  ('美', 2),
#  ('需', 2),
#  ('越', 2),
#  ('男女', 2),
#  ('无论', 2),
#  ('无论是', 2),
#  ('同价', 2),
#  ('同价位', 2),
#  ('适中', 2),
#  ('100', 2),
#  ...]

# %%
font = r'msjh.ttc'
my_wordcloud = WordCloud(background_color="white",font_path=font,collocations=False, width=2400, height=2400, margin=2)  
my_wordcloud.generate_from_frequencies(frequencies=Counter(terms))
plt.figure( figsize=(20,10), facecolor='k')
plt.imshow(my_wordcloud,interpolation='bilinear')
plt.axis("off")
plt.tight_layout(pad=0)
#顯示用
plt.show()
